# %% [markdown]
# # Grid Search do valor do Otimizador
# Fonte: https://machinelearningmastery.com/grid-search-hyperparameters-deep-learning-models-python-keras/

# %% [markdown]
# !pip install scikeras

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Flatten,Dropout, LSTM, Embedding, Input
from tensorflow import keras
from keras import layers

import pandas as pd
import tensorflow as tf
import numpy as np
import sys
np.set_printoptions(threshold=sys.maxsize)
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasClassifier
from tensorflow.keras.optimizers import Adam

def create_model():
  model=Sequential()
  model.add(LSTM(5 ,activation = 'relu',input_shape=(lags,1)))
  model.add(Dense(1, activation='sigmoid'))
  ## tamanho do lote e o número de épocas /
  return model

# %%
seed = 7
tf.random.set_seed(seed)

# %%
data = pd.read_csv('Inteligencia_Artificial/Trabalho de Conclusão de Curso/Base de Dados/2021/BBDC4_30m_2021.csv') 
data.head()
# Out:
#                         time       open       high        low      close  \
# 0  2021-01-04T10:00:00-03:00  21.814317  21.814317  21.505287  21.521135
# 1  2021-01-04T10:30:00-03:00  21.529059  21.576602  21.441896  21.497363
# 2  2021-01-04T11:00:00-03:00  21.505287  21.552830  21.473592  21.481516
# 3  2021-01-04T11:30:00-03:00  21.497363  21.521135  21.132867  21.188334
# 4  2021-01-04T12:00:00-03:00  21.188334  21.227953  21.085324  21.124943
#
#     Volume   Volume MA
# 0  1880012  1384668.55
# 1  1532703  1368010.00
# 2   877715  1345874.15
# 3  5465393  1548509.50
# 4  4150374  1694177.35

# %%
symbol = "close"
data = pd.DataFrame(data[symbol])
data.head()
data['return'] = np.log(data['close']/data['close'].shift(1))
temp = pd.DataFrame({})
temp['direction'] = np.where(data['return'] > 0, 1, 0)


lags = 4

cols = []
for lag in range(1, lags + 1):
     col = f'lag_{lag}'
     temp[col] = data['return'].shift(lag)
     cols.append(col)
temp.dropna(inplace=True)


temp.index = range(len(temp['direction']))

np.set_printoptions(threshold=False)

def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  Y = df_as_np[:,0]

  middle_matrix = df_as_np[:,1:5]

  X = middle_matrix.reshape((len(Y), middle_matrix.shape[1], 1))

  return X, Y.astype(int)

X, y = windowed_df_to_date_X_y(temp)

#-----------------------------------------------------------
# Define os conjuntos de dados de treinamento, teste e validação
#-----------------------------------------------------------
q_80 = int(len(X) * .8)

X_train, y_train = X[:q_80], y[:q_80]
X_test, y_test = X[q_80:], y[q_80:]




mu, std = X_train.mean(), X_train.std()
X_train = (X_train - mu) / std

X_test = (X_test - mu) / std

print(X_train)
print(X_test)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# [[[-0.59602594]
#   [-2.76167063]
#   [-0.14079378]
#   [-0.2149112 ]]
#
#  [[-1.5097588 ]
#   [-0.59602594]
#   [-2.76167063]
#   [-0.14079378]]
#
#  [[-0.37336195]
#   [-1.5097588 ]
#   [-0.59602594]
#   [-2.76167063]]
#
#  ...
#
#  [[ 1.05426085]
#   [-0.94370054]
#   [ 0.863996  ]
#   [-0.84834892]]
#
#  [[ 0.85997355]
#   [ 1.05426085]
#   [-0.94370054]
#   [ 0.863996  ]]
#
#  [[-1.12918969]
#   [ 0.85997355]
#   [ 1.05426085]
#   [-0.94370054]]]
# [[[-1.04008709]
#   [-1.12918969]
#   [ 0.85997355]
#   [ 1.05426085]]
#
#  [[-0.66188858]
#   [-1.04008709]
#   [-1.12918969]
#   [ 0.85997355]]
#
#  [[ 1.53532774]
#   [-0.66188858]
#   [-1.04008709]
#   [-1.12918969]]
#
#  ...
#
#  [[-0.51496261]
#   [ 0.53060969]
#   [ 1.26805957]
#   [-0.30797794]]
#
#  [[ 0.00782354]
#   [-0.51496261]
#   [ 0.53060969]
#   [ 1.26805957]]
#
#  [[-0.20167122]
#   [ 0.00782354]
#   [-0.51496261]
#   [ 0.53060969]]]
# ((3146, 4, 1), (3146,), (787, 4, 1), (787,))

# %%
from sklearn.model_selection import TimeSeriesSplit

dev_size=0.2 
n_splits=int((1//dev_size)-1)   # using // for integer division
tscv=TimeSeriesSplit(n_splits=n_splits) 
tscv
# Out:
# TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None)

# %%
# create model
# tamanho do lote e o número de épocas / 
model = KerasClassifier(model=create_model,loss="binary_crossentropy", optimizer="Adam", epochs=10, batch_size=40, verbose=0)

# %%
lista = []
for i in range(30):
  
  # define the grid search parameters
  learn_rate = [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3]
  param_grid = dict(optimizer__learning_rate=learn_rate)
  # https://towardsdatascience.com/cross-validation-and-grid-search-efa64b127c1b (CV parameter)
  # https://scikit-learn.org/stable/modules/cross_validation.html 
  #https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html
  #https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_indices.html#sphx-glr-auto-examples-model-selection-plot-cv-indices-py
  grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=tscv)
  grid_result = grid.fit(X_train, y_train)


  #Precisão

  print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
  
  means = grid_result.cv_results_['mean_test_score']
  stds = grid_result.cv_results_['std_test_score']
  params = grid_result.cv_results_['params']
  lista.append(grid_result.best_score_)
  for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

listSum = sum(lista)
med = listSum / len(lista)
print(med)
# Out:
# Best: 0.543681 using {'optimizer__learning_rate': 0.001}
# 0.515691 (0.032789) with: {'optimizer__learning_rate': 0.0001}
# 0.543681 (0.010812) with: {'optimizer__learning_rate': 0.001}
# 0.543257 (0.010231) with: {'optimizer__learning_rate': 0.01}
# 0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
# 0.478372 (0.039461) with: {'optimizer__learning_rate': 0.2}
# 0.521628 (0.039461) with: {'optimizer__learning_rate': 0.3}
# Best: 0.544105 using {'optimizer__learning_rate': 0.001}
# 0.539440 (0.007272) with: {'optimizer__learning_rate': 0.0001}
# 0.544105 (0.010661) with: {'optimizer__learning_rate': 0.001}
# 0.541561 (0.014593) with: {'optimizer__learning_rate': 0.01}
# 0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
# 0.543681 (0.010812) with: {'optimizer__learning_rate': 0.2}
# 0.543681 (0.010812) with: {'optimizer__learning_rate': 0.3}
# Best: 0.544529 using {'optimizer__learning_rate': 0.0001}
# 0.544529 (0.010018) with: {'optimizer__learning_rate': 0.0001}
# ...

# %%
Best: 0.543681 using {'optimizer__learning_rate': 0.001}
0.515691 (0.032789) with: {'optimizer__learning_rate': 0.0001}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.001}
0.543257 (0.010231) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.478372 (0.039461) with: {'optimizer__learning_rate': 0.2}
0.521628 (0.039461) with: {'optimizer__learning_rate': 0.3}
Best: 0.544105 using {'optimizer__learning_rate': 0.001}
0.539440 (0.007272) with: {'optimizer__learning_rate': 0.0001}
0.544105 (0.010661) with: {'optimizer__learning_rate': 0.001}
0.541561 (0.014593) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.2}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.3}
Best: 0.544529 using {'optimizer__learning_rate': 0.0001}
0.544529 (0.010018) with: {'optimizer__learning_rate': 0.0001}
0.541561 (0.011995) with: {'optimizer__learning_rate': 0.001}
0.544105 (0.012174) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.2}
0.522477 (0.039860) with: {'optimizer__learning_rate': 0.3}
Best: 0.544105 using {'optimizer__learning_rate': 0.0001}
0.544105 (0.010405) with: {'optimizer__learning_rate': 0.0001}
0.543257 (0.010994) with: {'optimizer__learning_rate': 0.001}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.2}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.3}
Best: 0.543681 using {'optimizer__learning_rate': 0.1}
0.511450 (0.013584) with: {'optimizer__learning_rate': 0.0001}
0.543257 (0.010231) with: {'optimizer__learning_rate': 0.001}
0.540712 (0.008876) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.2}
0.521204 (0.040049) with: {'optimizer__learning_rate': 0.3}
Best: 0.543681 using {'optimizer__learning_rate': 0.01}
0.529686 (0.010405) with: {'optimizer__learning_rate': 0.0001}
0.542833 (0.011676) with: {'optimizer__learning_rate': 0.001}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.504665 (0.044757) with: {'optimizer__learning_rate': 0.2}
0.521628 (0.039461) with: {'optimizer__learning_rate': 0.3}
Best: 0.544105 using {'optimizer__learning_rate': 0.01}
0.524597 (0.016696) with: {'optimizer__learning_rate': 0.0001}
0.541561 (0.009652) with: {'optimizer__learning_rate': 0.001}
0.544105 (0.010196) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.504665 (0.044757) with: {'optimizer__learning_rate': 0.2}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.3}
Best: 0.544529 using {'optimizer__learning_rate': 0.001}
0.526293 (0.010912) with: {'optimizer__learning_rate': 0.0001}
0.544529 (0.010018) with: {'optimizer__learning_rate': 0.001}
0.541561 (0.007934) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.2}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.3}
Best: 0.543681 using {'optimizer__learning_rate': 0.01}
0.536472 (0.018737) with: {'optimizer__learning_rate': 0.0001}
0.535623 (0.014654) with: {'optimizer__learning_rate': 0.001}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.522901 (0.037699) with: {'optimizer__learning_rate': 0.2}
0.517388 (0.041504) with: {'optimizer__learning_rate': 0.3}
Best: 0.543681 using {'optimizer__learning_rate': 0.1}
0.518660 (0.029388) with: {'optimizer__learning_rate': 0.0001}
0.540288 (0.013518) with: {'optimizer__learning_rate': 0.001}
0.542833 (0.009652) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.482612 (0.041504) with: {'optimizer__learning_rate': 0.2}
0.483461 (0.041200) with: {'optimizer__learning_rate': 0.3}
Best: 0.543681 using {'optimizer__learning_rate': 0.01}
0.539440 (0.015582) with: {'optimizer__learning_rate': 0.0001}
0.540712 (0.006812) with: {'optimizer__learning_rate': 0.001}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.2}
0.517388 (0.041504) with: {'optimizer__learning_rate': 0.3}
Best: 0.548770 using {'optimizer__learning_rate': 0.001}
0.486853 (0.035156) with: {'optimizer__learning_rate': 0.0001}
0.548770 (0.007296) with: {'optimizer__learning_rate': 0.001}
0.539864 (0.017206) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.504665 (0.044757) with: {'optimizer__learning_rate': 0.2}
0.478372 (0.039461) with: {'optimizer__learning_rate': 0.3}
Best: 0.543681 using {'optimizer__learning_rate': 0.001}
0.511874 (0.039479) with: {'optimizer__learning_rate': 0.0001}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.001}
0.539864 (0.017143) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.2}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.3}
Best: 0.543681 using {'optimizer__learning_rate': 0.001}
0.511026 (0.022909) with: {'optimizer__learning_rate': 0.0001}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.001}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.521628 (0.039461) with: {'optimizer__learning_rate': 0.2}
0.504665 (0.044757) with: {'optimizer__learning_rate': 0.3}
Best: 0.543681 using {'optimizer__learning_rate': 0.2}
0.505513 (0.013833) with: {'optimizer__learning_rate': 0.0001}
0.542833 (0.010661) with: {'optimizer__learning_rate': 0.001}
0.536472 (0.019332) with: {'optimizer__learning_rate': 0.01}
0.526293 (0.033019) with: {'optimizer__learning_rate': 0.1}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.2}
0.521628 (0.039461) with: {'optimizer__learning_rate': 0.3}
Best: 0.544953 using {'optimizer__learning_rate': 0.01}
0.509754 (0.027432) with: {'optimizer__learning_rate': 0.0001}
0.543681 (0.009818) with: {'optimizer__learning_rate': 0.001}
0.544953 (0.009368) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.478372 (0.039461) with: {'optimizer__learning_rate': 0.2}
0.504665 (0.044757) with: {'optimizer__learning_rate': 0.3}
Best: 0.544105 using {'optimizer__learning_rate': 0.01}
0.514843 (0.019637) with: {'optimizer__learning_rate': 0.0001}
0.540288 (0.010405) with: {'optimizer__learning_rate': 0.001}
0.544105 (0.010405) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.495335 (0.044757) with: {'optimizer__learning_rate': 0.2}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.3}
Best: 0.544953 using {'optimizer__learning_rate': 0.0001}
0.544953 (0.009596) with: {'optimizer__learning_rate': 0.0001}
0.541561 (0.012040) with: {'optimizer__learning_rate': 0.001}
0.539864 (0.003174) with: {'optimizer__learning_rate': 0.01}
0.542409 (0.012129) with: {'optimizer__learning_rate': 0.1}
0.517388 (0.041504) with: {'optimizer__learning_rate': 0.2}
0.482612 (0.041504) with: {'optimizer__learning_rate': 0.3}
Best: 0.544105 using {'optimizer__learning_rate': 0.001}
0.477947 (0.023696) with: {'optimizer__learning_rate': 0.0001}
0.544105 (0.011395) with: {'optimizer__learning_rate': 0.001}
0.544105 (0.011395) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.2}
0.504665 (0.044757) with: {'optimizer__learning_rate': 0.3}
Best: 0.543681 using {'optimizer__learning_rate': 0.1}
0.527566 (0.030540) with: {'optimizer__learning_rate': 0.0001}
0.541985 (0.013624) with: {'optimizer__learning_rate': 0.001}
0.540712 (0.006812) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.517812 (0.041669) with: {'optimizer__learning_rate': 0.2}
0.504665 (0.044757) with: {'optimizer__learning_rate': 0.3}
Best: 0.544953 using {'optimizer__learning_rate': 0.0001}
0.544953 (0.021017) with: {'optimizer__learning_rate': 0.0001}
0.542409 (0.011108) with: {'optimizer__learning_rate': 0.001}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.2}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.3}
Best: 0.544105 using {'optimizer__learning_rate': 0.01}
0.482612 (0.040358) with: {'optimizer__learning_rate': 0.0001}
0.542833 (0.010912) with: {'optimizer__learning_rate': 0.001}
0.544105 (0.010405) with: {'optimizer__learning_rate': 0.01}
0.517388 (0.041504) with: {'optimizer__learning_rate': 0.1}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.2}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.3}
Best: 0.544529 using {'optimizer__learning_rate': 0.0001}
0.544529 (0.009910) with: {'optimizer__learning_rate': 0.0001}
0.544529 (0.009910) with: {'optimizer__learning_rate': 0.001}
0.541561 (0.007934) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.517388 (0.041504) with: {'optimizer__learning_rate': 0.2}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.3}
Best: 0.544953 using {'optimizer__learning_rate': 0.01}
0.523325 (0.038678) with: {'optimizer__learning_rate': 0.0001}
0.543257 (0.011568) with: {'optimizer__learning_rate': 0.001}
0.544953 (0.011583) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.2}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.3}
Best: 0.545802 using {'optimizer__learning_rate': 0.001}
0.501272 (0.034749) with: {'optimizer__learning_rate': 0.0001}
0.545802 (0.013742) with: {'optimizer__learning_rate': 0.001}
0.540712 (0.008113) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.2}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.3}
Best: 0.543681 using {'optimizer__learning_rate': 0.1}
0.525869 (0.038370) with: {'optimizer__learning_rate': 0.0001}
0.543257 (0.011236) with: {'optimizer__learning_rate': 0.001}
0.535199 (0.008835) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.2}
0.517388 (0.041504) with: {'optimizer__learning_rate': 0.3}
Best: 0.543681 using {'optimizer__learning_rate': 0.001}
0.497031 (0.021624) with: {'optimizer__learning_rate': 0.0001}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.001}
0.541985 (0.007843) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.2}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.3}
Best: 0.543681 using {'optimizer__learning_rate': 0.1}
0.539016 (0.015594) with: {'optimizer__learning_rate': 0.0001}
0.543681 (0.010089) with: {'optimizer__learning_rate': 0.001}
0.542833 (0.009652) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.2}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.3}
Best: 0.545802 using {'optimizer__learning_rate': 0.001}
0.517812 (0.011568) with: {'optimizer__learning_rate': 0.0001}
0.545802 (0.009233) with: {'optimizer__learning_rate': 0.001}
0.539440 (0.005194) with: {'optimizer__learning_rate': 0.01}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.1}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.2}
0.543681 (0.010812) with: {'optimizer__learning_rate': 0.3}
Best: 0.542409 using {'optimizer__learning_rate': 0.001}
0.540288 (0.013518) with: {'optimizer__learning_rate': 0.0001}
0.542409 (0.012129) with: {'optimizer__learning_rate': 0.001}
0.536047 (0.002614) with: {'optimizer__learning_rate': 0.01}
0.504665 (0.044757) with: {'optimizer__learning_rate': 0.1}
0.495335 (0.044757) with: {'optimizer__learning_rate': 0.2}
0.521628 (0.039461) with: {'optimizer__learning_rate': 0.3}

# %%
Best: 0.543681 using {'optimizer__learning_rate': 0.001}
Best: 0.544105 using {'optimizer__learning_rate': 0.001}
Best: 0.544529 using {'optimizer__learning_rate': 0.0001}
Best: 0.544105 using {'optimizer__learning_rate': 0.0001}
Best: 0.543681 using {'optimizer__learning_rate': 0.1}
Best: 0.543681 using {'optimizer__learning_rate': 0.01}
Best: 0.544105 using {'optimizer__learning_rate': 0.01}
Best: 0.544529 using {'optimizer__learning_rate': 0.001}
Best: 0.543681 using {'optimizer__learning_rate': 0.01}
Best: 0.543681 using {'optimizer__learning_rate': 0.1}
Best: 0.543681 using {'optimizer__learning_rate': 0.01}
Best: 0.548770 using {'optimizer__learning_rate': 0.001}
Best: 0.543681 using {'optimizer__learning_rate': 0.001}
Best: 0.543681 using {'optimizer__learning_rate': 0.001}
Best: 0.543681 using {'optimizer__learning_rate': 0.2}
Best: 0.544953 using {'optimizer__learning_rate': 0.01}
Best: 0.544105 using {'optimizer__learning_rate': 0.01}
Best: 0.544953 using {'optimizer__learning_rate': 0.0001}
Best: 0.544105 using {'optimizer__learning_rate': 0.001}
Best: 0.543681 using {'optimizer__learning_rate': 0.1}
Best: 0.544953 using {'optimizer__learning_rate': 0.0001}
Best: 0.544105 using {'optimizer__learning_rate': 0.01}
Best: 0.544529 using {'optimizer__learning_rate': 0.0001}
Best: 0.544953 using {'optimizer__learning_rate': 0.01}
--> Best: 0.545802 using {'optimizer__learning_rate': 0.001}
Best: 0.543681 using {'optimizer__learning_rate': 0.1}
Best: 0.543681 using {'optimizer__learning_rate': 0.001}
Best: 0.543681 using {'optimizer__learning_rate': 0.1}
Best: 0.545802 using {'optimizer__learning_rate': 0.001}
Best: 0.542409 using {'optimizer__learning_rate': 0.001}
